# %% [markdown]
# <a href="https://colab.research.google.com/github/palombarini1207/677/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aluno = {
"Nome" : "Ana",
"idade": 17,
"Curso": "Ciência da Computação"
}
print(aluno["Nome"])
# Out:
# Ana

# %%
numeros = {1,1,2,2,3,3,4,4,5}
numeros.remove= [3]
print(numeros)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3541/2190052639.py in <cell line: 0>()
#       1 numeros = {1,1,2,2,3,3,4,4,5}
# ----> 2 numeros.remove= [3]
#       3 print(numeros)
#
# AttributeError: 'set' object attribute 'remove' is read-only

# %%
#DICIONARIO
aluno = {
    "nome": "Daniel",
    "idade": 16,
    "curso": "Informática"
}

print(aluno)

# %%
aluno = {
    "nome": "Daniel",
    "idade": 16,
    "curso": "Informática"
}

print(aluno["nome"])
print(aluno["idade"])
print(aluno["curso"])
# Out:
# Daniel
# 16
# Informática

# %%
produto = {
    "nome": "Arroz",
    "preço": 25.00,
    "estoque": 10
}

produto["preço"] = 30.00

print(produto)
# Out:
# {'nome': 'Arroz', 'preço': 30.0, 'estoque': 10}

# %%
aluno = {
    "nome": "Daniel",
    "idade": 16
}

aluno["curso"] = "Informática"

print(aluno)
# Out:
# {'nome': 'Daniel', 'idade': 16, 'curso': 'Informática'}

# %%
filme = {
    "título": "Vingadores",
    "ano": 2019,
    "gênero": "Ação",
    "nota": 9.0
}

print(filme["título"])
print(filme["ano"])
print(filme["gênero"])
print(filme["nota"])
# Out:
# Vingadores
# 2019
# Ação
# 9.0

# %%
#TUPLA
numeros = {1, 2, 3, 4, 5}

print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
numeros = {1, 2, 2, 3, 3, 3, 4, 5}

print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
frutas = {"maçã", "banana", "laranja"}

frutas.add("morango")

print(frutas)
# Out:
# {'laranja', 'banana', 'maçã', 'morango'}

# %%
cores = {"vermelho", "azul", "verde", "amarelo"}

cores.remove("verde")

print(cores)
# Out:
# {'amarelo', 'vermelho', 'azul'}

# %%
nomes = ["Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi", "Gael", "Theo", "Theo"]

nomes = set(nomes)

print(nomes)
# Out:
# {'Maitê', 'Theo', 'Yris', 'Luna', 'Ravi', 'Gael'}
