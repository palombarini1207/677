# %% [markdown]
# <a href="https://colab.research.google.com/github/palombarini1207/677/blob/main/220526.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero= 0
while numero< 5:
 print (numero)
 numero+= 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#senha simples

senha = ""

try:

   while senha != 1234:
       senha = int (input("digite sua senha: "))
       print("acesso liberado")


except :
   print("A senha deve conter apenas numeros:")
# Out:
# digite sua senha: 1234
# acesso liberado

# %%
# contagem regressiva 10 até 0 e imprimir uma mensagem "acabou!"

contador = 10

while contador >- 0:
  print (contador)
  contador -=1
  print("acabou!")
# Out:
# 10
# acabou!
# 9
# acabou!
# 8
# acabou!
# 7
# acabou!
# 6
# acabou!
# 5
# acabou!
# 4
# acabou!
# 3
# acabou!
# 2
# acabou!
# 1
# acabou!

# %%
# calculadora com as 4 operações
# opção 1 somar
# opçção 2 subtrair
# opção 3 multiplicar
# opção 4 divisão
# opção 5 sair

opcao = 0
a = 0
b = 0

while opcao != 5:



   opcao = int (input("digite uma opçãode 1 a 4 ou 5 para sair: "))

if opcao == 1:
    a = int (input("digite um numero: "))
    b = int (input("digite um nuemro: "))

    print(f"total da soma igual : {a + b}")

elif opcao == 2:
    a = int (input("digite um numero: "))
    b = int (input("digite um nuemro: "))

    print(f"total da soma igual : {a - b}")

elif opcao == 3:
    a = int (input("digite um numero: "))
    b = int (input("digite um nuemro: "))

    print(f"total da soma igual : {a * b}")

elif opcao == 4:
    a = int (input("digite um numero: "))
    b = int (input("digite um nuemro: "))

    print(f"total da soma igual : {a / b}")

else:
 print ("volte sempre")
# Out:
# digite uma opçãode 1 a 4 ou 5 para sair: 4
# digite uma opçãode 1 a 4 ou 5 para sair: 1
# digite uma opçãode 1 a 4 ou 5 para sair: 4
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2
# digite uma opçãode 1 a 4 ou 5 para sair: 2

# %%
# Escrever um programa que recebe as notas do aluno referente aos 4 bimestres
# calcular a media das notas e imprimir a mensagem de aprovado, recuperação ou reprovado

# nota maior ou igual a 7 aprovado
# nota maior ou igual a 5 recuperação
# nota menor que 5 reprovado




# Programa para calcular a média do aluno

while True:
    nota1 = float(input("Digite a nota do 1º bimestre: "))
    nota2 = float(input("Digite a nota do 2º bimestre: "))
    nota3 = float(input("Digite a nota do 3º bimestre: "))
    nota4 = float(input("Digite a nota do 4º bimestre: "))

    media = (nota1 + nota2 + nota3 + nota4) / 4

    print(f"Média final: {media:.2f}")

    if media >= 7:
        print("Aluno aprovado")
    elif media >= 5:
        print("Aluno em recuperação")
    else:
        print("Aluno reprovado")

    continuar = input("Deseja calcular outra média? (s/n): ")

    if continuar != "s":
        print("Programa encerrado.")
        break
