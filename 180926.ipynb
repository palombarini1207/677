# %% [markdown]
# <a href="https://colab.research.google.com/github/palombarini1207/677/blob/main/180926.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alunos= ["Leticia" , "Anderson" , "Marcos"]
alunos.append("Rafaela")
alunos.remove("Rafaela")
print(alunos)
# Out:
# ['Leticia', 'Anderson', 'Marcos']

# %%
frutas = ["maçã" , "banana" , "laranja" , "morango"]
print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'morango']

# %%
nomes = ["Rebeca", "Guilherme" , "Melissa" , "Kayra"]
print(nomes[0])
# Out:
# Rebeca

# %%
cores = ["vermelho" , "azul" , "verde"]
cores[1]=("Amarelo")
print(cores)
# Out:
# ['vermelho', 'Amarelo', 'verde']

# %%
alunos = ["Nicolas", "Wendel", "Pyetra"]

alunos.append("Petros")

print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
animais = ["cachorro", "gato", "coelho", "passarinho"]

animais.remove("coelho")

print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %%
#Tuplas

meses = ("Janeiro", "Fevereiro", "Março", "Abril")

print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %%
numeros = (10, 20, 30, 40, 50)

print(numeros[0])
print(numeros[2])
print(numeros[4])
# Out:
# 10
# 30
# 50

# %%
aluno = ("Daniel", 16, "Informática")

print(aluno[0])
print(aluno[1])
print(aluno[2])
# Out:
# Daniel
# 16
# Informática

# %%
cores = ["vermelho", "azul", "verde"]


cores[1] = "amarelo"

print(cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %%
numeros = (2, 4, 2, 6, 2, 8, 10)

print(numeros.count(2))
# Out:
# 3
