# %% [markdown]
# <a href="https://colab.research.google.com/github/palombarini1207/677/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 Crie um programa que solicite um usuario
nome= str(input(" Digite seu nome:"))
idade= int(input(" Digite sua idade: "))
Altura= float(input(" Digite sua altura :"))
print(f"Olá {nome} ")
print(f"Qual sua idade? {idade}")
print(f"Você tem {Altura} metros de altura?!")
# Out:
#  Digite seu nome:Daniel
#  Digite sua idade: 16
#  Digite sua altura :1.90
# Olá Daniel
# Qual sua idade? 16
# Você tem 1.9 metros de altura?!
